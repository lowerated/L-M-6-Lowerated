# %% [markdown]
# # LRA: Review Analysis

# %%
# %pip install lowerated

# %%
import pandas as pd

df = pd.read_csv("dump/Rating System/Sentiment Analysis/Data/movie_review.csv")
df.rename(
    columns={
        "fold_id":"movie_id"
    },
    inplace=True
)
df
# Out:
#        movie_id cv_tag  html_id  sent_id  \
# 0             0  cv000    29590        0
# 1             0  cv000    29590        1
# 2             0  cv000    29590        2
# 3             0  cv000    29590        3
# 4             0  cv000    29590        4
# ...         ...    ...      ...      ...
# 64715         9  cv999    14636       20
# 64716         9  cv999    14636       21
# 64717         9  cv999    14636       22
# 64718         9  cv999    14636       23
# 64719         9  cv999    14636       24
#
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# 2      to say moore and campbell thoroughly researche...  pos
# 3      the book ( or " graphic novel , " if you will ...  pos
# 4      in other words , don't dismiss this film becau...  pos
# ...                                                  ...  ...
# ...

# %% [markdown]
# ### Rate

# %%
from lowerated.rate.entity import Entity
from dotenv import load_dotenv
import os

load_dotenv()

openai_key = os.environ["OPENAI_API_KEY"]

# csv file path
file_path = "dump/Rating System/Sentiment Analysis/Data/movie_review.csv"
#review column
review_column = "text"

# Example usage
if __name__ == "__main__":

    entity = Entity(name="Movie")
    attributes = entity.get_attributes()

    rating = entity.rate(
        file_path=file_path, review_column=review_column, range=(0,100), openai_key=openai_key)

    print(rating)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17469/2752204818.py in ?()
#      16
#      17     entity = Entity(name="Movie")
#      18     attributes = entity.get_attributes()
#      19
# ---> 20     rating = entity.rate(
#      21         file_path=file_path, review_column=review_column, openai_key=openai_key)
#      22
#      23     print(rating)
#
# ~/stuff/Lowerated/products/L-M-6-Lowerated/lowerated/rate/entity.py in ?(self, reviews, file_path, download_link, review_column, openai_key)
#      72                                         "support": 0.9
#      73                            }
#      74         """
#      75         if reviews is None:
# ---> 76             reviews = read_reviews(file_path=file_path,
#      77                                    download_link=download_link, review_column=review_column)
#      78
#      79         if reviews:
#
# ...
