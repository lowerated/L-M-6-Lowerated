# %% [markdown]
# # LRA: Review Analysis

# %%
# %pip install lowerated
# Out:
# Requirement already satisfied: lowerated in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (0.1.3)
# Requirement already satisfied: numpy in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from lowerated) (1.23.5)
# Requirement already satisfied: python-dotenv in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from lowerated) (1.0.1)
# Requirement already satisfied: websockets in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from lowerated) (12.0)
# Requirement already satisfied: fastapi in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from lowerated) (0.111.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (2.7.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (4.12.1)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (3.10.3)
# Requirement already satisfied: email_validator>=2.0.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi->lowerated) (2.1.1)
# Requirement already satisfied: uvicorn>=0.12.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi->lowerated) (0.30.1)
# Requirement already satisfied: dnspython>=2.0.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi->lowerated) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi->lowerated) (3.7)
# Requirement already satisfied: typer>=0.12.3 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from fastapi-cli>=0.0.2->fastapi->lowerated) (0.12.3)
# Requirement already satisfied: anyio in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->lowerated) (4.4.0)
# Requirement already satisfied: certifi in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->lowerated) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->lowerated) (1.0.5)
# Requirement already satisfied: sniffio in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->lowerated) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi->lowerated) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi->lowerated) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->lowerated) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->lowerated) (2.18.4)
# Requirement already satisfied: click>=7.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from uvicorn>=0.12.0->uvicorn[standard]>=0.12.0->fastapi->lowerated) (8.1.7)
# Requirement already satisfied: httptools>=0.5.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi->lowerated) (0.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi->lowerated) (6.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi->lowerated) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi->lowerated) (0.22.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->fastapi->lowerated) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->lowerated) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->lowerated) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->lowerated) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->lowerated) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/wisalkhanmv/anaconda3/envs/lowerated/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->lowerated) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("dump/Rating System/Sentiment Analysis/Data/movie_review.csv")
df.rename(
    columns={
        "fold_id":"movie_id"
    },
    inplace=True
)
df
# Out:
#        movie_id cv_tag  html_id  sent_id  \
# 0             0  cv000    29590        0
# 1             0  cv000    29590        1
# 2             0  cv000    29590        2
# 3             0  cv000    29590        3
# 4             0  cv000    29590        4
# ...         ...    ...      ...      ...
# 64715         9  cv999    14636       20
# 64716         9  cv999    14636       21
# 64717         9  cv999    14636       22
# 64718         9  cv999    14636       23
# 64719         9  cv999    14636       24
#
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# 2      to say moore and campbell thoroughly researche...  pos
# 3      the book ( or " graphic novel , " if you will ...  pos
# 4      in other words , don't dismiss this film becau...  pos
# ...                                                  ...  ...
# 64715  that lack of inspiration can be traced back to...  neg
# 64716  like too many of the skits on the current inca...  neg
# 64717  after watching one of the " roxbury " skits on...  neg
# 64718   bump unsuspecting women , and . . . that's all .  neg
# 64719  after watching _a_night_at_the_roxbury_ , you'...  neg
#
# [64720 rows x 6 columns]

# %% [markdown]
# ### Rate

# %%
from lowerated.rate.entity import Entity
from dotenv import load_dotenv
import os

load_dotenv()

openai_key = os.environ["OPENAI_API_KEY"]

# csv file path
file_path = "dump/Rating System/Sentiment Analysis/Data/movie_review.csv"
#review column
review_column = "review"

# Example usage
if __name__ == "__main__":

    entity = Entity(name="Movie")
    attributes = entity.get_attributes()

    rating = entity.rate(
        file_path=file_path, openai_key=openai_key)

    print(rating)
# Out:
# Python-dotenv could not parse statement starting at line 6
# Python-dotenv could not parse statement starting at line 7
# Python-dotenv could not parse statement starting at line 8
# Python-dotenv could not parse statement starting at line 9
# Python-dotenv could not parse statement starting at line 10
# Python-dotenv could not parse statement starting at line 11
# Python-dotenv could not parse statement starting at line 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 18
#      15 entity = Entity(name="Movie")
#      16 attributes = entity.get_attributes()
# ---> 18 rating = entity.rate(
#      19     file_path=file_path, openai_key=openai_key)
#      21 print(rating)
#
# File ~/stuff/Lowerated/products/L-M-6-Lowerated/lowerated/rate/entity.py:125, in Entity.rate(self, reviews, file_path, download_link, openai_key)
#     122         return
#     124 if reviews:
# --> 125     probabilities = get_probabilities(
#     126         reviews=reviews, entity=self.name, attributes=self.attributes, key=openai_key)
#     127     return probabilities
#     128 else:
#
# File ~/stuff/Lowerated/products/L-M-6-Lowerated/lowerated/rate/utils.py:84, in get_probabilities(reviews, entity, attributes, key)
#      81 client = OpenAI()
#      83 # Join all reviews into a single string for context
# ---> 84 reviews_text = "\n".join(reviews)
#      86 # Prepare the prompt template
#      87 prompt_template = f"""Analyze the following reviews for the entity '{entity}' and provide probabilities for the following attributes as a JSON object with values ranging from -1 to 1: {', '.join(attributes)}.
#      88
#      89 -1 means, sentiment of that attibute is negative
#    (...)
#      95
#      96 Reviews: """
#
# TypeError: sequence item 0: expected str instance, int found
